# %% [markdown]
# # Make Tables for GPS
#
# Claire Punturieri
# September 5, 2026

# %%
library(tidyverse)
# Out:
# Warning: package 'ggplot2' was built under R version 4.4.3
# Warning: package 'tibble' was built under R version 4.4.3
# Warning: package 'tidyr' was built under R version 4.4.3
# Warning: package 'readr' was built under R version 4.4.3
# Warning: package 'purrr' was built under R version 4.4.3
# Warning: package 'dplyr' was built under R version 4.4.3
# Warning: package 'stringr' was built under R version 4.4.3
# Warning: package 'forcats' was built under R version 4.4.3
# Warning: package 'lubridate' was built under R version 4.4.3
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## Demographics (table 1)
#
# Load in study_dates.

# %%
study_dates <- read_csv(file.path(path_shared,"study_dates_gps.csv"),
                        show_col_types = FALSE)

# %% [markdown]
# Pull list of subject IDs with at least one month data, credible lapse reporting, and sufficient GPS data.

# %%
subids_dates <- study_dates |>  
  pull(subid) |>  
  unique()

# %% [markdown]
# Clean up file and filter down to only subjects used for GPS.

# %%
dem_data <- read_csv(file.path(path_shared, "screen.csv"),
                     show_col_types = FALSE) |> 
  select(subid,  
         age = dem_1, 
         sex = dem_2, 
         race = dem_3, 
         hispanic = dem_4,
         education = dem_5,
         work = dem_6,
         income = dem_7,
         contains("dsm")) |> 
         mutate(hispanic = if_else(str_detect(hispanic, "Yes"), "1", "0")) |>  
    mutate(american_native = ifelse(str_detect(race,"American Indian/Alaska Native"),1,0),
        asian = ifelse(str_detect(race,"Asian"),1,0),
        pacific = ifelse(str_detect(race,"Native Hawaiian or Other Pacific Islander"),1,0),
        black = ifelse(str_detect(race,"Black/African American"),1,0),
        white = ifelse(str_detect(race,"White/Caucasian"),1,0),
        other = ifelse(str_detect(race,"Other/Multiracial"),1,0),
        ) |> 
  filter(subid %in% subids_dates)

# %% [markdown]
# Create table.

# %%
dem_data |>
  mutate(
    age_group = cut(
      age,
      breaks = c(18, 25, 35, 45, 55, 65, Inf),
      labels = c(
        "18-24",
        "25-34",
        "35-44",
        "45-54",
        "55-64",
        "65+"
      ),
      right = FALSE
    ),
    income_group = cut(
      income,
      breaks = c(0, 25000, 50000, 100000, 150000, Inf),
      labels = c(
        "<$25,000",
        "$25,000-$49,999",
        "$50,000-$99,999",
        "$100,000-$149,999",
        "≥$150,000"
      ),
    right = FALSE
  ),
  hispanic = if_else(hispanic == 1, "Yes", "No")) |>
  gtsummary::tbl_summary(include = c(age_group, sex,
                                     education, work,
                                     race, hispanic, income_group),
                         label = list(
                           age_group ~ "Age",
                           sex ~ "Sex At Birth",
                           race ~ "Race",
                           hispanic ~ "Ethnicity",
                           income_group ~ "Income"
                         )) |> 
  gtsummary::bold_labels()
# Out:
# <div id="oxkzreagig" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#oxkzreagig table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #oxkzreagig thead, #oxkzreagig tbody, #oxkzreagig tfoot, #oxkzreagig tr, #oxkzreagig td, #oxkzreagig th {
#   border-style: none;
# }
#
# #oxkzreagig p {
#   margin: 0;
#   padding: 0;
# }
#
# #oxkzreagig .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #oxkzreagig .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #oxkzreagig .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #oxkzreagig .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #oxkzreagig .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #oxkzreagig .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #oxkzreagig .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #oxkzreagig .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #oxkzreagig .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #oxkzreagig .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #oxkzreagig .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #oxkzreagig .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #oxkzreagig .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #oxkzreagig .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #oxkzreagig .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #oxkzreagig .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #oxkzreagig .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #oxkzreagig .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #oxkzreagig .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #oxkzreagig .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #oxkzreagig .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #oxkzreagig .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #oxkzreagig .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #oxkzreagig .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #oxkzreagig .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-widt

# %% [markdown]
# ## Fairness by auROC (table 2)

# %%
contrast_dem_auroc <- read_csv((here::here(path_models, "pp_fairness_contrast_full.csv")))
# Out:
# Rows: 5 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): contrast
# dbl (4): probability, median, lower, upper
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
contrast_dem_auroc |> 
  mutate(`Bayesian CI` = str_c("[", round(lower, 3), ", ", round(upper, 3), "]"),
         `Median auROC Difference` = as.character(round(median, 3)),
         Probability = sprintf("%.3f", probability)) |> 
  select(Contrast = contrast, `Median auROC Difference`, `Bayesian CI`, Probability) |> 
  knitr::kable() |> 
  kable_classic() |> 
  kableExtra::column_spec(1, width = "25em") |> 
  kableExtra::add_footnote(#label = footnote_table_model,
                           notation = "none",
                           escape = FALSE)
# Out:
# <table class=" lightable-classic" style='font-family: "Arial Narrow", "Source Sans Pro", sans-serif; margin-left: auto; margin-right: auto;'>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Contrast </th>
#    <th style="text-align:left;"> Median auROC Difference </th>
#    <th style="text-align:left;"> Bayesian CI </th>
#    <th style="text-align:left;"> Probability </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;width: 25em; "> Male vs Female </td>
#    <td style="text-align:left;"> 0.017 </td>
#    <td style="text-align:left;"> [-0.013, 0.048] </td>
#    <td style="text-align:left;"> 0.169 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> White/Caucasian vs Non-White and/or Hispanic </td>
#    <td style="text-align:left;"> 0.039 </td>
#    <td style="text-align:left;"> [-0.015, 0.094] </td>
#    <td style="text-align:left;"> 0.119 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> Above 2018 Poverty Line vs Below 2018 Poverty Line </td>
#    <td style="text-align:left;"> -0.016 </td>
#    <td style="text-align:left;"> [-0.047, 0.014] </td>
#    <td style="text-align:left;"> 0.810 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> Younger than 55 vs Older than 55 </td>
#    <td style="text-align:left;"> 0.078 </td>
#    <td style="text-align:left;"> [0.034, 0.125] </td>
#    <td style="text-align:left;"> 0.002 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> College or more vs Less than college </td>
#    <td style="text-align:left;"> -0.053 </td>
#    <td style="text-align:left;"> [-0.087, -0.019] </td>
#    <td style="text-align:left;"> 0.994 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Fairness by LL (table 3)

# %%
contrast_dem_ll <- read_csv((here::here(path_models, "pp_fairness_contrast_logloss.csv")))
# Out:
# Rows: 5 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): contrast
# dbl (4): probability, median, lower, upper
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
contrast_dem_ll |> 
  mutate(`Bayesian CI` = str_c("[", round(lower, 3), ", ", round(upper, 3), "]"),
         `Median mean Log Loss Difference` = as.character(round(median, 3)),
         Probability = sprintf("%.3f", probability)) |> 
  select(Contrast = contrast, `Median mean Log Loss Difference`, `Bayesian CI`, Probability) |> 
  knitr::kable() |> 
  kable_classic() |> 
  kableExtra::column_spec(1, width = "25em") |> 
  kableExtra::add_footnote(#label = footnote_table_model,
                           notation = "none",
                           escape = FALSE)
# Out:
# <table class=" lightable-classic" style='font-family: "Arial Narrow", "Source Sans Pro", sans-serif; margin-left: auto; margin-right: auto;'>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Contrast </th>
#    <th style="text-align:left;"> Median mean Log Loss Difference </th>
#    <th style="text-align:left;"> Bayesian CI </th>
#    <th style="text-align:left;"> Probability </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;width: 25em; "> Male vs Female </td>
#    <td style="text-align:left;"> -0.057 </td>
#    <td style="text-align:left;"> [-0.085, -0.03] </td>
#    <td style="text-align:left;"> 1.000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> White/Caucasian vs Non-White and/or Hispanic </td>
#    <td style="text-align:left;"> 0.052 </td>
#    <td style="text-align:left;"> [0, 0.103] </td>
#    <td style="text-align:left;"> 0.051 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> Above 2018 Poverty Line vs Below 2018 Poverty Line </td>
#    <td style="text-align:left;"> -0.05 </td>
#    <td style="text-align:left;"> [-0.074, -0.027] </td>
#    <td style="text-align:left;"> 1.000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> Younger than 55 vs Older than 55 </td>
#    <td style="text-align:left;"> -0.028 </td>
#    <td style="text-align:left;"> [-0.079, 0.022] </td>
#    <td style="text-align:left;"> 0.819 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> College or more vs Less than college </td>
#    <td style="text-align:left;"> 0.019 </td>
#    <td style="text-align:left;"> [-0.004, 0.043] </td>
#    <td style="text-align:left;"> 0.087 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Bin counts for calibration plots (tables 4 + 5)

# %%
probs <- read_csv(here::here(path_models, "outer_preds_v25_nested_2_x_5_6_x_5_full.csv"))
# Out:
# Rows: 68616 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): label
# dbl (4): id_obs, outer_split_num, prob_raw, prev_inner
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Table 4 - collapsed across folds.

# %%
cal_raw |>
  group_by(bins, probs) |>
  summarise(
    mean_pred = mean(prob),
    mean_lapse = mean(lapse),
    n = n(),
    .groups = "drop"
  ) |>
  mutate(mean_pred = (round(mean_pred, digits = 3) * 100),
         mean_lapse = (round(mean_lapse, digits = 3)) * 100) |> 
  select(`Bin width` = bins, `Mean Probability of Lapse` = mean_pred,
         `Mean Lapse Percentage` = mean_lapse, Count = n) |>
  knitr::kable() |> 
  kable_classic() |> 
  kableExtra::column_spec(1, width = "25em") |> 
  kableExtra::add_footnote(#label = footnote_table_model,
                           notation = "none",
                           escape = FALSE)
# Out:
# <table class=" lightable-classic" style='font-family: "Arial Narrow", "Source Sans Pro", sans-serif; margin-left: auto; margin-right: auto;'>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Bin width </th>
#    <th style="text-align:right;"> Mean Probability of Lapse </th>
#    <th style="text-align:right;"> Mean Lapse Percentage </th>
#    <th style="text-align:right;"> Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 6.4 </td>
#    <td style="text-align:right;"> 4.9 </td>
#    <td style="text-align:right;"> 52192 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 12.8 </td>
#    <td style="text-align:right;"> 14.9 </td>
#    <td style="text-align:right;"> 15771 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 23.1 </td>
#    <td style="text-align:right;"> 23.6 </td>
#    <td style="text-align:right;"> 606 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.3,0.4] </td>
#    <td style="text-align:right;"> 32.3 </td>
#    <td style="text-align:right;"> 21.7 </td>
#    <td style="text-align:right;"> 46 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.4,0.5] </td>
#    <td style="text-align:right;"> 40.0 </td>
#    <td style="text-align:right;"> 0.0 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Table 5 - separated by fold.

# %%
cal_raw |>
  group_by(bins, probs, outer_split_num) |>
  summarise(
    mean_pred = mean(prob),
    mean_lapse = mean(lapse),
    n = n(),
    .groups = "drop"
  ) |> 
  arrange(outer_split_num) |>
  mutate(mean_pred = (round(mean_pred, digits = 3) * 100),
         mean_lapse = (round(mean_lapse, digits = 3)) * 100) |> 
  select(`Bin width` = bins, `Fold` = outer_split_num,
         `Mean Probability of Lapse` = mean_pred,
         `Mean Lapse Percentage` = mean_lapse, Count = n) |>
  knitr::kable() |> 
  kable_classic() |> 
  kableExtra::column_spec(1, width = "25em") |> 
  kableExtra::add_footnote(#label = footnote_table_model,
                           notation = "none",
                           escape = FALSE)
# Out:
# <table class=" lightable-classic" style='font-family: "Arial Narrow", "Source Sans Pro", sans-serif; margin-left: auto; margin-right: auto;'>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Bin width </th>
#    <th style="text-align:right;"> Fold </th>
#    <th style="text-align:right;"> Mean Probability of Lapse </th>
#    <th style="text-align:right;"> Mean Lapse Percentage </th>
#    <th style="text-align:right;"> Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 6.5 </td>
#    <td style="text-align:right;"> 5.1 </td>
#    <td style="text-align:right;"> 1975 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 12.2 </td>
#    <td style="text-align:right;"> 13.8 </td>
#    <td style="text-align:right;"> 356 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 23.6 </td>
#    <td style="text-align:right;"> 0.0 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 7.6 </td>
#    <td style="text-align:right;"> 4.2 </td>
#    <td style="text-align:right;"> 1433 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 13.7 </td>
#    <td style="text-align:right;"> 9.3 </td>
#    <td style="text-align:right;"> 841 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 23.1 </td>
#    <td style="text-align:right;"> 33.3 </td>
#    <td style="text-align:right;"> 3 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 7.7 </td>
#    <td style="text-align:right;"> 4.5 </td>
#    <td style="text-align:right;"> 1477 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 12.6 </td>
#    <td style="text-align:right;"> 17.1 </td>
#    <td style="text-align:right;"> 692 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 23.9 </td>
#    <td style="text-align:right;"> 4.8 </td>
#    <td style="text-align:right;"> 21 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 5.6 </td>
#    <td style="text-align:right;"> 6.2 </td>
#    <td style="text-align:right;"> 2117 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 12.2 </td>
#    <td style="text-align:right;"> 11.3 </td>
#    <td style="text-align:right;"> 291 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 8.0 </td>
#    <td style="text-align:right;"> 3.5 </td>
#    <td style="text-align:right;"> 1353 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 11.6 </td>
#    <td style="text-align:right;"> 17.7 </td>
#    <td style="text-align:right;"> 876 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 5.7 </td>
#    <td style="text-align:right;"> 6.7 </td>
#    <td style="text-align:right;"> 1781 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 12.9 </td>
#    <td style="text-align:right;"> 13.8 </td>
#    <td style="text-align:right;"> 600 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 21.7 </td>
#    <td style="text-align:right;"> 37.0 </td>
#    <td style="text-align:right;"> 27 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 7.3 </td>
#    <td style="text-align:right;"> 1.9 </td>
#    <td style="text-align:right;"> 1700 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 12.9 </td>
#    <td style="text-align:right;"> 16.0 </td>
#    <td style="text-align:right;"> 667 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 22.6 </td>
#    <td style="text-align:right;"> 35.2 </td>
#    <td style="text-align:right;"> 54 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> 5.9 </td>
#    <td style="text-align:right;"> 4.0 </td>
#    <td style="text-align:right;"> 1786 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> 12.8 </td>
#    <td style="text-align:right;"> 15.9 </td>
#    <td style="text-align:right;"> 389 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> 21.4 </td>
#    <td style="text-align:right;"> 0.0 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 9 </td>
#    <td style="text-align:right;"> 5.5 </td>
#    <td style="text-align:right;"> 4.7 </td>
#    <td style="text-align:right;"> 1766 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 9 </td>
#    <td style="text-align:right;"> 13.6 </td>
#    <td style="text-align:right;"> 14.3 </td>
#    <td style="text-align:right;"> 463 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 9 </td>
#    <td style="text-align:right;"> 21.2 </td>
#    <td style="text-align:right;"> 42.9 </td>
#    <td style="text-align:right;"> 7 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 10 </td>
#    <td style="text-align:right;"> 5.5 </td>
#    <td style="text-align:right;"> 6.5 </td>
#    <td style="text-align:right;"> 1899 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 10 </td>
#    <td style="text-align:right;"> 13.7 </td>
#    <td style="text-align:right;"> 21.3 </td>
#    <td style="text-align:right;"> 258 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.2,0.3] </td>
#    <td style="text-align:right;"> 10 </td>
#    <td style="text-align:right;"> 21.6 </td>
#    <td style="text-align:right;"> 24.2 </td>
#    <td style="text-align:right;"> 33 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0,0.1] </td>
#    <td style="text-align:right;"> 11 </td>
#    <td style="text-align:right;"> 8.0 </td>
#    <td style="text-align:right;"> 2.7 </td>
#    <td style="text-align:right;"> 1663 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;width: 25em; "> (0.1,0.2] </td>
#    <td style="text-align:right;"> 11 </td>
#    <td style="text-align:right;"> 12.4 </td>
#    <td style="text-align:right;"> 24.2 </td>
#    <td style="text-align:right;"> 661 </td>
#   </tr>
